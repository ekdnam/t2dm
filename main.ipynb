# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data/data.xlsx")
print(df)
# Out:
#                               PMID  \
# 0     insulin+mortality+odds ratio
# 1                         30694322
# 2                         19318384
# 3                         29488676
# 4                         12771873
# ...                            ...
# 2578                      28419317
# 2579                      26831610
# 2580                      24088548
# 2581                      15287931
# 2582                      21148630
#
#                                                   Title  \
# 0                                                   NaN
# 1     Effect of Hydrocortisone Therapy Initiated 7 t...
# 2     Intensive versus conventional glucose control ...
# 3     Treatment with insulin is associated with wors...
# 4     Continuous insulin infusion reduces mortality ...
# ...                                                 ...
# 2578  High-Dose and High-Frequency Lanreotide Autoge...
# 2579  Effect of telmisartan on histological activity...
# ...
